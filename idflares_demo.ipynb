# %% [markdown]
# ## Demo for idflares.py

# %%
import idflares

from matplotlib import pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (14.0, 8.0)

# %% [markdown]
# Test it on long-cadence data first.

# %%
idflares.main("../data/01_koi256_Q02_LC.hdf5",check=True)
